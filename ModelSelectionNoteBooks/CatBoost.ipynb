# %% [markdown]
# Import the required Libraries for our problem.

# %%
# !pwd
# Out:
# /home/khashayar/Desktop/projects/dotamodel

# %%
import pandas as pd
import torch
from torch import nn
import numpy as np
from tqdm import tqdm
from tqdm.notebook import trange, tqdm

from scipy.sparse import lil_matrix
from scipy.sparse import hstack
from scipy.sparse import coo_matrix

from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier
import torch.optim as optim

# %% [markdown]
# Use GPU for our computations

# %%
print(torch.cuda.device_count())
if torch.cuda.is_available():  
  dev = "cuda:0" 
else:  
  dev = "cpu"  
device = torch.device(dev)  
print(device)
# Out:
# 0
# cpu

# %% [markdown]
# Import the Data inside

# %%
df = pd.read_csv('dota_games.csv')
df
# Out:
#               GameID   TimeStamp     GameSEQ  Leavers  RadiantWin  Pick1Rad  \
# 0         5702035339  1605433074  4795818304        0           1        75
# 1         5702036092  1605433111  4795818235        0           0        22
# 2         5702039715  1605433280  4795818283        1           0        21
# 3         5702041041  1605433346  4795848331        0           0        26
# 4         5702041315  1605433377  4795818256        1           1        12
# ...              ...         ...         ...      ...         ...       ...
# 16913394  5782875527  1610421230  4869157490        1           0        88
# 16913395  5782876220  1610421300  4869155380        1           1        20
# 16913396  5782878555  1610421525  4869149137        1           0        31
# 16913397  5782879828  1610421645  4869156196        1           0       129
# 16913398  5782879865  1610421626  4869157731        0           1        14
#
#           Pick2Rad  Pick3Rad  Pick4Rad  Pick5Rad  Pick1Dir  Pick2Dir  \
# 0               35        68        14        44       101        51
# 1               41         6         9        26        39        36
# 2               26        84       102         8        14        71
# 3               67        79        42        35        21       104
# 4               22         2       128        79        25        93
# ...            ...       ...       ...       ...       ...       ...
# 16913394        75        54        78        23        85        76
# 16913395        40         8        63        77         9         5
# 16913396        26        98        54       126        27       103
# 16913397        30        41        11        68       104       101
# 16913398        61        77        13        33       110       105
#
#           Pick3Dir  Pick4Dir  Pick5Dir  skill_level
# 0               38        67        74          NaN
# 1               93        31        85          NaN
# 2              129        47        18          NaN
# 3                1       119        10          NaN
# 4               98        75        41          NaN
# ...            ...       ...       ...          ...
# 16913394        32        70       114          NaN
# 16913395        14         1        60          NaN
# 16913396        13         8        32          3.0
# 16913397        32        31       106          2.0
# 16913398        93        36        23          NaN
#
# [16913399 rows x 16 columns]

# %% [markdown]
# Filter out games that have no leavers. Games with Leavers=0

# %%
df_no_leavers = df.query('Leavers==0')
df_no_leavers
# Out:
#               GameID   TimeStamp     GameSEQ  Leavers  RadiantWin  Pick1Rad  \
# 0         5702035339  1605433074  4795818304        0           1        75
# 1         5702036092  1605433111  4795818235        0           0        22
# 3         5702041041  1605433346  4795848331        0           0        26
# 6         5702044125  1605433531  4795863372        0           1        54
# 7         5702044805  1605433556  4795853616        0           1        79
# ...              ...         ...         ...      ...         ...       ...
# 16913388  5782874424  1610421130  4869157247        0           1        64
# 16913389  5782874452  1610421125  4869156928        0           1         3
# 16913391  5782874747  1610421160  4869156248        0           1        21
# 16913393  5782875467  1610421194  4869156483        0           1        86
# 16913398  5782879865  1610421626  4869157731        0           1        14
#
#           Pick2Rad  Pick3Rad  Pick4Rad  Pick5Rad  Pick1Dir  Pick2Dir  \
# 0               35        68        14        44       101        51
# 1               41         6         9        26        39        36
# 3               67        79        42        35        21       104
# 6               26       105        85       113        86         5
# 7               31        67        97        21        64       107
# ...            ...       ...       ...       ...       ...       ...
# 16913388        21        28        54        46        25         7
# 16913389       100        63        54       120       123        64
# 16913391        27         2        44        61        87       107
# 16913393        87        77        63        59        30       123
# 16913398        61        77        13        33       110       105
#
#           Pick3Dir  Pick4Dir  Pick5Dir  skill_level
# 0               38        67        74          NaN
# 1               93        31        85          NaN
# 3                1       119        10          NaN
# 6               70        60        75          NaN
# 7              104         6       126          NaN
# ...            ...       ...       ...          ...
# 16913388        77         1        59          NaN
# 16913389        29         1        11          3.0
# 16913391        67        71        48          3.0
# 16913393         6        56        23          NaN
# 16913398        93        36        23          NaN
#
# [13930628 rows x 16 columns]

# %% [markdown]
# Separate X and y.

# %%
X = df_no_leavers.loc[:,'Pick1Rad':'Pick5Dir']
y = df_no_leavers['RadiantWin']

df_size = df_no_leavers.shape[0]
train_data, vali_data ,  test_data = df_no_leavers.iloc[0:int(df_size*0.85),:] , df_no_leavers.iloc[int(df_size*0.85):int(df_size*0.95),:] , df_no_leavers.iloc[int(df_size*0.95):,:]

# %%
del df
del df_no_leavers

# %% [markdown]
# Data Loader

# %%
from torch.utils.data import DataLoader,Dataset
import random

class game_datasets(Dataset):

  def __init__(self,rawdata):
    X = rawdata.loc[:,'Pick1Rad':'Pick5Dir']
    y = rawdata['RadiantWin']
    self.x = torch.tensor(X.values)
    self.y = torch.tensor(y.values)

  def __getitem__(self,index):
    return self.x[index],self.y[index]
    
  def __len__(self):
    return len(self.y)

# %% [markdown]
# Transform every batch of information and also add games for earlier picks

# %%
def game_datasets_transform_X(data_X,mode=None,device="cpu"):
  # If mode is none only the 10 picks are added.
  # If mode is equal to 10 all possible combinations are added aswell.
  # If mode is either 1,2,3,4,5 the picks with those scenarios are only added.

  if mode is not None:
    picks = data_X.t()
    picks = picks.to(device)
    #1st picks
    picks_rad = torch.zeros(data_X.shape[0],150,device=device)
    picks_rad[range(picks_rad.shape[0]), picks[0]] = -1
    picks_dire = torch.zeros(data_X.shape[0],150,device=device)
    picks_dire[range(picks_dire.shape[0]), picks[5]] = 1
    if mode==10:
      res = torch.cat([picks_rad,picks_dire],dim=0) 
    if mode==1:
      return torch.cat([picks_rad,picks_dire],dim=0) 

    #2nd picks
    picks_rad[range(picks_rad.shape[0]), picks[1]] = -1
    picks_dire[range(picks_dire.shape[0]), picks[6]] = 1
    if mode==10:
      res = torch.cat([res,picks_rad,picks_dire],dim=0)
    if mode==2:
      return torch.cat([picks_rad,picks_dire],dim=0) 

    #3rd picks
    picks_rad[range(picks_rad.shape[0]), picks[5:7]] = 1
    picks_dire[range(picks_dire.shape[0]), picks[0:2]] = -1

    picks_rad[range(picks_rad.shape[0]), picks[2]] = -1
    picks_dire[range(picks_dire.shape[0]), picks[7]] = 1
    if mode==10:
      res = torch.cat([res,picks_rad,picks_dire],dim=0)
    if mode==3:
      return torch.cat([picks_rad,picks_dire],dim=0)  

    #4th picks
    picks_rad[range(picks_rad.shape[0]), picks[3]] = -1
    picks_dire[range(picks_dire.shape[0]), picks[8]] = 1
    if mode==10:
      res = torch.cat([res,picks_rad,picks_dire],dim=0)
    if mode==4:
      return torch.cat([picks_rad,picks_dire],dim=0)

    #5th picks
    picks_rad[range(picks_rad.shape[0]), picks[7:9]] = 1
    picks_dire[range(picks_dire.shape[0]), picks[2:4]] = -1

    picks_rad[range(picks_rad.shape[0]), picks[4]] = -1
    picks_dire[range(picks_dire.shape[0]), picks[9]] = 1
    if mode==10:
      res = torch.cat([res,picks_rad,picks_dire],dim=0)
    if mode==5:
      return torch.cat([picks_rad,picks_dire],dim=0)

    #All picks (Only for mode 10)
    picks_rad[range(picks_rad.shape[0]), picks[9]] = 1
    res = torch.cat([res,picks_rad],dim=0) 
    return res
  
  else:
    picks = data_X.t()
    picks = picks.to(device)
    picks_all = torch.zeros(data_X.shape[0],150,device=device)
    picks_all[range(picks_all.shape[0]), picks[0:5]]= -1
    picks_all[range(picks_all.shape[0]), picks[5:10]]= 1
    return picks_all

# %% [markdown]
# Also Y must be transformed to match X transformation if mode is anythig either that None

# %%
def game_datasets_transform_Y(data_Y,mode=None):
  #y_trans = []
  if mode==None:
    return data_Y
  
  y = data_Y.numpy()
  #for i, y in enumerate(data_Y.numpy()):
  if mode <10:
    # y_trans.append(y)
    # y_trans.append(y)
    res = np.tile(y,2)
  else:
    res = np.tile(y,11)
    # res = np.concatenate([y,y])
    # for _ in range(10):
    # #  y_trans.append(y)
    #   res = np.concatenate([res,y])
        
  return torch.tensor(res)

# %% [markdown]
# Define Model:

# %%
def showaccs_cat(cat_classes,test_data):
  print('here')
  picks = []
  acc = []
  for i in range(1,6):
    test_data_set = game_datasets(test_data)
    test_data_loader = DataLoader(test_data_set,batch_size=30000)
    test_data_iter = iter(test_data_loader)
    del test_data_set
    del test_data_loader
    correct = 0
    total = 0
    counter = 0
    for data in test_data_iter:
      counter+=1
      if counter%30 == 0:
        print(f"At data {counter} of {len(test_data_iter)} in accuracy calc")
      x,y = data
      x = game_datasets_transform_X(x,i)
      y = game_datasets_transform_Y(y,i)
      x = x.view(-1,150).float()
      y = y.view(-1,1).float()
      x = x.numpy()
      y = y.numpy().ravel()
      output = cat_classes[i].predict(x)
      res = output
      res[res<=0.5] = 0
      res[res>0.5] = 1
      correct += np.sum(res==y)
      total += len(output)
    picks.append(i)
    acc.append(correct/total * 100)
  chart_data = pd.DataFrame({'pick_numbers':picks,'accuracy':acc})
  final_acc = (acc[0] + 1.5*acc[1] + 3*acc[2] + 4*acc[3] + 7*acc[4]) / 16.5 
  return final_acc,chart_data

# %%
#iterations = [10,100,1000]
iterations = ["Free"]
#learning_rates = [0.0001,0.001,0.01,0.1,1]
learning_rates = ["Free"]

have_init_model = False
for learning_rate in learning_rates:
    for iters in iterations:
        print(f"iter {iters} and learning rate {learning_rate}")
        #cat_classes = [CatBoostClassifier(random_seed=10,logging_level="Silent",iterations=iters,learning_rate=learning_rate) for i in range(6)]
        cat_classes = [CatBoostClassifier(random_seed=10,logging_level="Silent") for i in range(6)]
        train_data_set = game_datasets(train_data)
        train_data_loader = DataLoader(train_data_set,batch_size=30000)
        train_data_iter = iter(train_data_loader)
        del train_data_set
        counter = 0
        for data in train_data_iter:
            counter +=1
            if counter%30 == 0:
                print(f"At data {counter} of {len(train_data_iter)} in training stage")
            for class_number in range(1,6):
                x,y = data
                x = game_datasets_transform_X(x,class_number)
                y = game_datasets_transform_Y(y,class_number)
                x = x.view(-1,150).float()
                y = y.view(-1,1).float()
                x = x.numpy()
                y = y.numpy().ravel()
                if have_init_model == False:
                  cat_classes[class_number].fit(x,y)
                else:
                  init_class_model = cat_classes[class_number]
                  cat_classes[class_number].fit(x,y,init_model=init_class_model)
            have_init_model = True
        for class_number in range(1,6):
            #learning_to_file = learning_rate * 10000
            learning_to_file = "Free"
            cat_classes[class_number].save_model(f"model_{class_number}_iter_{iters}_rate_{learning_to_file}")
        del train_data_iter
        print('Done Training')
        print('Train Acc:  ')
        print(showaccs_cat(cat_classes,train_data))
        print('Valid Acc:  ')
        print(showaccs_cat(cat_classes,test_data))
# Out:
# iter Free and learning rate Free
# At data 30 of 395 in training stage
# At data 60 of 395 in training stage
# At data 90 of 395 in training stage
# At data 120 of 395 in training stage
# At data 150 of 395 in training stage
# At data 180 of 395 in training stage
# At data 210 of 395 in training stage
# At data 240 of 395 in training stage
# At data 270 of 395 in training stage
# At data 300 of 395 in training stage
# At data 330 of 395 in training stage
# At data 360 of 395 in training stage
# At data 390 of 395 in training stage
# ---------------------------------------------------------------------------
# CatBoostError                             Traceback (most recent call last)
# <ipython-input-14-6e6ba2b34a89> in <module>
#      35         for class_number in range(1,6):
#      36             learning_to_file = learning_rate * 10000
# ---> 37             cat_classes[class_number].save_model(f"model_{class_number}_iter_{iters}_rate_{learning_to_file}")
#      38         del train_data_iter
#      39         print('Done Training')
#
# ~/miniconda3/lib/python3.8/site-packages/catboost/core.py in save_model(self, fname, format, export_parameters, pool)
#    2850                 embedding_features=self._get_embedding_feature_indices() if not isinstance(pool, FeaturesData) else None
#    2851             )
# -> 2852         self._save_model(fname, format, export_parameters, pool)
#    2853
#    2854     def load_model(self, fname=None, format='cbm', stream=None, blob=None):
#
# ~/miniconda3/lib/python3.8/site-packages/catboost/core.py in _save_model(self, output_file, format, export_parameters, pool)
#    1454                 params_string = json.dumps(export_parameters, cls=_NumpyAwareEncoder)
#    1455
# -> 1456             self._object._save_model(output_file, format, params_string, pool)
#    1457
#    1458     def _load_model(self, model_file, format):
#
# _catboost.pyx in _catboost._CatBoost._save_model()
#
# _catboost.pyx in _catboost._CatBoost._save_model()
#
# CatBoostError: (File name too long) util/system/file.cpp:848: can't open "model_1_iter_Free_rate_..." with mode WrOnly|CreateAlways|Seq (0x00000034)

# %%
cat_classes = [CatBoostClassifier() for i in range(6)]
for class_number in range(1,6):
    #learning_to_file = learning_rate * 10000
    iters = "Free"
    learning_to_file = "Free"
    cat_classes[class_number].load_model(f"model_{class_number}_iter_{iters}_rate_{learning_to_file}")
print("Loaded")
print('Done Training')
print('Train Acc:  ')
print(showaccs_cat(cat_classes,train_data))
print('Valid Acc:  ')
print(showaccs_cat(cat_classes,test_data))
# Out:
# Loaded
# Done Training
# Train Acc:
# here
# At data 30 of 395 in accuracy calc
# At data 60 of 395 in accuracy calc
# At data 90 of 395 in accuracy calc
# At data 120 of 395 in accuracy calc
# At data 150 of 395 in accuracy calc
# At data 180 of 395 in accuracy calc
# At data 210 of 395 in accuracy calc
# At data 240 of 395 in accuracy calc
# At data 270 of 395 in accuracy calc
# At data 300 of 395 in accuracy calc
# At data 330 of 395 in accuracy calc
# At data 360 of 395 in accuracy calc
# At data 390 of 395 in accuracy calc
# At data 30 of 395 in accuracy calc
# At data 60 of 395 in accuracy calc
# At data 90 of 395 in accuracy calc
# At data 120 of 395 in accuracy calc
# At data 150 of 395 in accuracy calc
# At data 180 of 395 in accuracy calc
# At data 210 of 395 in accuracy calc
# At data 240 of 395 in accuracy calc
# At data 270 of 395 in accuracy calc
# At data 300 of 395 in accuracy calc
# At data 330 of 395 in accuracy calc
# At data 360 of 395 in accuracy calc
# At data 390 of 395 in accuracy calc
# At data 30 of 395 in accuracy calc
# At data 60 of 395 in accuracy calc
# At data 90 of 395 in accuracy calc
# At data 120 of 395 in accuracy calc
# At data 150 of 395 in accuracy calc
# At data 180 of 395 in accuracy calc
# At data 210 of 395 in accuracy calc
# At data 240 of 395 in accuracy calc
# At data 270 of 395 in accuracy calc
# At data 300 of 395 in accuracy calc
# At data 330 of 395 in accuracy calc
# At data 360 of 395 in accuracy calc
# At data 390 of 395 in accuracy calc
# At data 30 of 395 in accuracy calc
# At data 60 of 395 in accuracy calc
# At data 90 of 395 in accuracy calc
# At data 120 of 395 in accuracy calc
# At data 150 of 395 in accuracy calc
# At data 180 of 395 in accuracy calc
# At data 210 of 395 in accuracy calc
# At data 240 of 395 in accuracy calc
# At data 270 of 395 in accuracy calc
# At data 300 of 395 in accuracy calc
# At data 330 of 395 in accuracy calc
# At data 360 of 395 in accuracy calc
# At data 390 of 395 in accuracy calc
# At data 30 of 395 in accuracy calc
# At data 60 of 395 in accuracy calc
# At data 90 of 395 in accuracy calc
# At data 120 of 395 in accuracy calc
# At data 150 of 395 in accuracy calc
# At data 180 of 395 in accuracy calc
# At data 210 of 395 in accuracy calc
# At data 240 of 395 in accuracy calc
# At data 270 of 395 in accuracy calc
# At data 300 of 395 in accuracy calc
# At data 330 of 395 in accuracy calc
# At data 360 of 395 in accuracy calc
# At data 390 of 395 in accuracy calc
# (52.89712067478838,    pick_numbers   accuracy
# 0             1  53.258010
# 1             2  52.527546
# 2             3  52.372082
# 3             4  52.585585
# 4             5  53.327797)
# Valid Acc:
# here
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-fc04d165154a> in <module>
#      10 print(showaccs_cat(cat_classes,train_data))
#      11 print('Valid Acc:  ')
# ---> 12 print(showaccs_cat(cat_classes,test_data))
#
# <ipython-input-6-ff8478042cc2> in showaccs_cat(cat_classes, test_data)
#      23       x = x.numpy()
#      24       y = y.numpy().ravel()
# ---> 25       output = cat_classes[i].predict(x)
#      26       res = output
#      27       res[res<=0.5] = 0
#
# ~/miniconda3/lib/python3.8/site-packages/catboost/core.py in predict(self, data, prediction_type, ntree_start, ntree_end, thread_count, verbose)
#    4593                   with log probability for every class for each object.
#    4594         """
# -> 4595         return self._predict(data, prediction_type, ntree_start, ntree_end, thread_count, verbose, 'predict')
#    4596
#    4597     def predict_proba(self, data, ntree_start=0, ntree_end=0, thread_count=-1, verbose=None):
#
# ~/miniconda3/lib/python3.8/site-packages/catboost/core.py in _predict(self, data, prediction_type, ntree_start, ntree_end, thread_count, verbose, parent_method_name)
#    2091         self._validate_prediction_type(prediction_type)
#    2092
# -> 2093         predictions = self._base_predict(data, prediction_type, ntree_start, ntree_end, thread_count, verbose)
#    2094         return predictions[0] if data_is_single_object else predictions
#    2095
#
# ~/miniconda3/lib/python3.8/site-packages/catboost/core.py in _base_predict(self, pool, prediction_type, ntree_start, ntree_end, thread_count, verbose)
#    1416
#    1417     def _base_predict(self, pool, prediction_type, ntree_start, ntree_end, thread_count, verbose):
# -> 1418         return self._object._base_predict(pool, prediction_type, ntree_start, ntree_end, thread_count, verbose)
#    1419
#    1420     def _base_virtual_ensembles_predict(self, pool, prediction_type, ntree_end, virtual_ensembles_count, thread_count, verbose):
#
# KeyboardInterrupt:
